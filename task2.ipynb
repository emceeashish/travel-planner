# %% [markdown]
# <a href="https://colab.research.google.com/github/emceeashish/travel-planner/blob/main/task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# !apt update
# !apt install -y libopencv-dev pkg-config
# Out:
# Collecting nvcc4jupyter
#   Downloading nvcc4jupyter-1.2.1-py3-none-any.whl.metadata (5.1 kB)
# Downloading nvcc4jupyter-1.2.1-py3-none-any.whl (10 kB)
# Installing collected packages: nvcc4jupyter
# Successfully installed nvcc4jupyter-1.2.1
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmp3ysmc9l8".
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [345 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,227 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,860 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,205 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,598 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,633 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,287 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,573 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,966 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,411 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [37.2 kB]
# Hit:22 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:23 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:24 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 38.3 MB in 33s (1,166 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 54 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libbz2-dev libpkgconf3 libreadline-dev
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   at-spi2-core gsettings-desktop-schemas gstreamer1.0-plugins-base
#   libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data libatspi2.0-0 libavcodec-dev
#   libavformat-dev libavutil-dev libcdparanoia0 libcharls2 libdc1394-dev
#   libdouble-conversion3 libexif-dev libexif-doc libexif12 libgdcm-dev
#   libgdcm3.0 libgl2ps1.4 libglew2.2 libgphoto2-6 libgphoto2-dev
#   libgphoto2-l10n libgphoto2-port12 libgstreamer-plugins-base1.0-0 libgtk-3-0
#   libgtk-3-bin libgtk-3-common libilmbase-dev libilmbase25
#   libopencv-calib3d-dev libopencv-calib3d4.5d libopencv-contrib-dev
#   libopencv-contrib4.5d libopencv-core-dev libopencv-core4.5d
#   libopencv-dnn-dev libopencv-dnn4.5d libopencv-features2d-dev
#   libopencv-features2d4.5d libopencv-flann-dev libopencv-flann4.5d
#   libopencv-highgui-dev libopencv-highgui4.5d libopencv-imgcodecs-dev
#   libopencv-imgcodecs4.5d libopencv-imgproc-dev libopencv-imgproc4.5d
#   libopencv-ml-dev libopencv-ml4.5d libopencv-objdetect-dev
#   libopencv-objdetect4.5d libopencv-photo-dev libopencv-photo4.5d
#   libopencv-shape-dev libopencv-shape4.5d libopencv-stitching-dev
#   libopencv-stitching4.5d libopencv-superres-dev libopencv-superres4.5d
#   libopencv-video-dev libopencv-video4.5d libopencv-videoio-dev
#   libopencv-videoio4.5d libopencv-videostab-dev libopencv-videostab4.5d
#   libopencv-viz-dev libopencv-viz4.5d libopencv4.5-java libopencv4.5d-jni
#   libopenexr-dev libopenexr25 liborc-0.4-0 libraw1394-dev libraw1394-tools
#   librsvg2-common libsocket++1 libswresample-dev libswscale-dev libtbb-dev
#   libtbb12 libtbbmalloc2 libvisual-0.4-0 libvtk9.1 libxcomposite1 libxtst6
#   opencv-data session-migration
# Suggested packages:
#   gvfs glew-utils gphoto2 libvisual-0.4-plugins opencv-doc libraw1394-doc
#   libtbb-doc vtk9-doc vtk9-examples
# The following packages will be REMOVED:
#   pkgconf r-base-dev
# The following NEW packages will be installed:
#   at-spi2-core gsettings-desktop-schemas gstreamer1.0-plugins-base
#   libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data libatspi2.0-0 libavcodec-dev
#   libavformat-dev libavutil-dev libcdparanoia0 libcharls2 libdc1394-dev
#   libdouble-conversion3 libexif-dev libexif-doc libexif12 libgdcm-dev
#   libgdcm3.0 libgl2ps1.4 libglew2.2 libgphoto2-6 libgphoto2-dev
#   libgphoto2-l10n libgphoto2-port12 libgstreamer-plugins-base1.0-0 libgtk-3-0
#   libgtk-3-bin libgtk-3-common libilmbase-dev libilmbase25
#   libopencv-calib3d-dev libopencv-calib3d4.5d libopencv-contrib-dev
#   libopencv-contrib4.5d libopencv-core-dev libopencv-core4.5d libopencv-dev
#   libopencv-dnn-dev libopencv-dnn4.5d libopencv-features2d-dev
#   libopencv-features2d4.5d libopencv-flann-dev libopencv-flann4.5d
#   libopencv-highgui-dev libopencv-highgui4.5d libopencv-imgcodecs-dev
#   libopencv-imgcodecs4.5d libopencv-imgproc-dev libopencv-imgproc4.5d
#   libopencv-ml-dev libopencv-ml4.5d libopencv-objdetect-dev
#   libopencv-objdetect4.5d libopencv-photo-dev libopencv-photo4.5d
#   libopencv-shape-dev libopencv-shape4.5d libopencv-stitching-dev
#   libopencv-stitching4.5d libopencv-superres-dev libopencv-superres4.5d
#   libopencv-video-dev libopencv-video4.5d libopencv-videoio-dev
#   libopencv-videoio4.5d libopencv-videostab-dev libopencv-videostab4.5d
#   libopencv-viz-dev libopencv-viz4.5d libopencv4.5-java libopencv4.5d-jni
#   libopenexr-dev libopenexr25 liborc-0.4-0 libraw1394-dev libraw1394-tools
#   librsvg2-common libsocket++1 libswresample-dev libswscale-dev libtbb-dev
#   libtbb12 libtbbmalloc2 libvisual-0.4-0 libvtk9.1 libxcomposite1 libxtst6
#   opencv-data pkg-config session-migration
# 0 upgraded, 91 newly installed, 2 to remove and 54 not upgraded.
# Need to get 68.0 MB of archives.
# After this operation, 323 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 pkg-config amd64 0.29.2-1ubuntu3 [48.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build2 [49.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liborc-0.4-0 amd64 1:0.4.32-2ubuntu0.1 [228 kB]
# Get:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-core4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,184 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.20.1-1ubuntu0.5 [848 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisual-0.4-0 amd64 0.4.0-17build2 [108 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-base amd64 1.20.1-1ubuntu0.5 [712 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavutil-dev amd64 7:4.4.2-0ubuntu0.22.04.1 [427 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libswresample-dev amd64 7:4.4.2-0ubuntu0.22.04.1 [78.0 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavcodec-dev amd64 7:4.4.2-0ubuntu0.22.04.1 [6,221 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavformat-dev amd64 7:4.4.2-0ubuntu0.22.04.1 [1,347 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcharls2 amd64 2.3.4-1 [87.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraw1394-dev amd64 2.1.2-2build2 [39.1 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdc1394-dev amd64 2.2.6-4 [116 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdouble-conversion3 amd64 3.1.7-4 [39.0 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexif12 amd64 0.6.24-1build1 [92.5 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexif-dev amd64 0.6.24-1build1 [113 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexif-doc all 0.6.24-1build1 [317 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsocket++1 amd64 1.12.13+git20131030.5d039ba-1 [84.3 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgdcm3.0 amd64 3.0.10-1build2 [1,830 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgdcm-dev amd64 3.0.10-1build2 [266 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgl2ps1.4 amd64 1.4.2+dfsg1-2 [43.5 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew2.2 amd64 2.2.0-4 [196 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgphoto2-port12 amd64 2.5.27-1build2 [57.6 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgphoto2-6 amd64 2.5.27-1build2 [727 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgphoto2-dev amd64 2.5.27-1build2 [34.3 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgphoto2-l10n all 2.5.27-1build2 [14.0 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2.2 [239 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2.2 [3,053 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-bin amd64 3.24.33-1ubuntu2.2 [69.6 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase25 amd64 2.5.7-2 [175 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase-dev amd64 2.5.7-2 [78.4 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtbbmalloc2 amd64 2021.5.0-7ubuntu2 [49.6 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtbb12 amd64 2021.5.0-7ubuntu2 [84.8 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtbb-dev amd64 2021.5.0-7ubuntu2 [191 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr25 amd64 2.5.7-1 [780 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr-dev amd64 2.5.7-1 [73.3 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libswscale-dev amd64 7:4.4.2-0ubuntu0.22.04.1 [206 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraw1394-tools amd64 2.1.2-2build2 [16.9 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:50 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-flann4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [154 kB]
# Get:51 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-imgproc4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,412 kB]
# Get:52 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-features2d4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [294 kB]
# Get:53 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-calib3d4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [723 kB]
# Get:54 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-core-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,997 kB]
# Get:55 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-flann-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [229 kB]
# Get:56 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-imgcodecs4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [148 kB]
# Get:57 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-highgui4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [96.9 kB]
# Get:58 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-imgproc-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,874 kB]
# Get:59 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-imgcodecs-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [218 kB]
# Get:60 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-videoio4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [213 kB]
# Get:61 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-videoio-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [333 kB]
# Get:62 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-highgui-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [150 kB]
# Get:63 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-ml4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [224 kB]
# Get:64 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-ml-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [316 kB]
# Get:65 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-features2d-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [391 kB]
# Get:66 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-calib3d-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,065 kB]
# Get:67 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-dnn4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,120 kB]
# Get:68 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-objdetect4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [196 kB]
# Get:69 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-video4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [200 kB]
# Get:70 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-contrib4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [3,680 kB]
# Get:71 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-dnn-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,724 kB]
# Get:72 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-objdetect-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [273 kB]
# Get:73 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-photo4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [205 kB]
# Get:74 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-photo-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [240 kB]
# Get:75 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-shape4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [69.5 kB]
# Get:76 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-video-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [270 kB]
# Get:77 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-shape-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [90.3 kB]
# Get:78 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-stitching4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [218 kB]
# Get:79 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-stitching-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [288 kB]
# Get:80 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-superres4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [65.1 kB]
# Get:81 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-superres-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [80.8 kB]
# Get:82 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-videostab4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [97.7 kB]
# Get:83 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-videostab-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [130 kB]
# Get:84 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libvtk9.1 amd64 9.1.0+really9.1.0+dfsg2-3build1+jammy1 [20.2 MB]
# Get:85 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-viz4.5d amd64 4.5.4+dfsg-9ubuntu4+jammy1 [130 kB]
# Get:86 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-viz-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [205 kB]
# Get:87 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-contrib-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [5,029 kB]
# Get:88 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv-dev amd64 4.5.4+dfsg-9ubuntu4+jammy1 [109 kB]
# Get:89 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv4.5d-jni amd64 4.5.4+dfsg-9ubuntu4+jammy1 [507 kB]
# Get:90 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libopencv4.5-java amd64 4.5.4+dfsg-9ubuntu4+jammy1 [1,002 kB]
# Get:91 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 opencv-data all 4.5.4+dfsg-9ubuntu4+jammy1 [1,371 kB]
# Fetched 68.0 MB in 3min 4s (369 kB/s)
# Extracting templates from packages: 100%
# (Reading database ... 121689 files and directories currently installed.)
# Removing r-base-dev (4.5.2-1.2204.0) ...
# dpkg: pkgconf: dependency problems, but removing anyway as you requested:
#  libsndfile1-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libmkl-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libglib2.0-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libfontconfig-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#
# Removing pkgconf (1.8.0-1) ...
# Removing 'diversion of /usr/bin/pkg-config to /usr/bin/pkg-config.real by pkgconf'
# Removing 'diversion of /usr/share/aclocal/pkg.m4 to /usr/share/aclocal/pkg.real.m4 by pkgconf'
# Removing 'diversion of /usr/share/man/man1/pkg-config.1.gz to /usr/share/man/man1/pkg-config.real.1.gz by pkgconf'
# Removing 'diversion of /usr/share/pkg-config-crosswrapper to /usr/share/pkg-config-crosswrapper.real by pkgconf'
# Selecting previously unselected package pkg-config.
# (Reading database ... 121666 files and directories currently installed.)
# Preparing to unpack .../00-pkg-config_0.29.2-1ubuntu3_amd64.deb ...
# Unpacking pkg-config (0.29.2-1ubuntu3) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../01-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../02-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../03-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../04-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../05-at-spi2-core_2.44.0-3_amd64.deb ...
# Unpacking at-spi2-core (2.44.0-3) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../06-libcdparanoia0_3.10.2+debian-14build2_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../07-liborc-0.4-0_1%3a0.4.32-2ubuntu0.1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../08-libgstreamer-plugins-base1.0-0_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../09-libvisual-0.4-0_0.4.0-17build2_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../10-gstreamer1.0-plugins-base_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../11-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../12-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../13-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libavutil-dev:amd64.
# Preparing to unpack .../14-libavutil-dev_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavutil-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libswresample-dev:amd64.
# Preparing to unpack .../15-libswresample-dev_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libswresample-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libavcodec-dev:amd64.
# Preparing to unpack .../16-libavcodec-dev_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavcodec-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libavformat-dev:amd64.
# Preparing to unpack .../17-libavformat-dev_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavformat-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libcharls2:amd64.
# Preparing to unpack .../18-libcharls2_2.3.4-1_amd64.deb ...
# Unpacking libcharls2:amd64 (2.3.4-1) ...
# Selecting previously unselected package libraw1394-dev:amd64.
# Preparing to unpack .../19-libraw1394-dev_2.1.2-2build2_amd64.deb ...
# Unpacking libraw1394-dev:amd64 (2.1.2-2build2) ...
# Selecting previously unselected package libdc1394-dev:amd64.
# Preparing to unpack .../20-libdc1394-dev_2.2.6-4_amd64.deb ...
# Unpacking libdc1394-dev:amd64 (2.2.6-4) ...
# Selecting previously unselected package libdouble-conversion3:amd64.
# Preparing to unpack .../21-libdouble-conversion3_3.1.7-4_amd64.deb ...
# Unpacking libdouble-conversion3:amd64 (3.1.7-4) ...
# Selecting previously unselected package libexif12:amd64.
# Preparing to unpack .../22-libexif12_0.6.24-1build1_amd64.deb ...
# Unpacking libexif12:amd64 (0.6.24-1build1) ...
# Selecting previously unselected package libexif-dev:amd64.
# Preparing to unpack .../23-libexif-dev_0.6.24-1build1_amd64.deb ...
# Unpacking libexif-dev:amd64 (0.6.24-1build1) ...
# Selecting previously unselected package libexif-doc.
# Preparing to unpack .../24-libexif-doc_0.6.24-1build1_all.deb ...
# Unpacking libexif-doc (0.6.24-1build1) ...
# Selecting previously unselected package libsocket++1:amd64.
# Preparing to unpack .../25-libsocket++1_1.12.13+git20131030.5d039ba-1_amd64.deb ...
# Unpacking libsocket++1:amd64 (1.12.13+git20131030.5d039ba-1) ...
# Selecting previously unselected package libgdcm3.0:amd64.
# Preparing to unpack .../26-libgdcm3.0_3.0.10-1build2_amd64.deb ...
# Unpacking libgdcm3.0:amd64 (3.0.10-1build2) ...
# Selecting previously unselected package libgdcm-dev.
# Preparing to unpack .../27-libgdcm-dev_3.0.10-1build2_amd64.deb ...
# Unpacking libgdcm-dev (3.0.10-1build2) ...
# Selecting previously unselected package libgl2ps1.4.
# Preparing to unpack .../28-libgl2ps1.4_1.4.2+dfsg1-2_amd64.deb ...
# Unpacking libgl2ps1.4 (1.4.2+dfsg1-2) ...
# Selecting previously unselected package libglew2.2:amd64.
# Preparing to unpack .../29-libglew2.2_2.2.0-4_amd64.deb ...
# Unpacking libglew2.2:amd64 (2.2.0-4) ...
# Selecting previously unselected package libgphoto2-port12:amd64.
# Preparing to unpack .../30-libgphoto2-port12_2.5.27-1build2_amd64.deb ...
# Unpacking libgphoto2-port12:amd64 (2.5.27-1build2) ...
# Selecting previously unselected package libgphoto2-6:amd64.
# Preparing to unpack .../31-libgphoto2-6_2.5.27-1build2_amd64.deb ...
# Unpacking libgphoto2-6:amd64 (2.5.27-1build2) ...
# Selecting previously unselected package libgphoto2-dev:amd64.
# Preparing to unpack .../32-libgphoto2-dev_2.5.27-1build2_amd64.deb ...
# Unpacking libgphoto2-dev:amd64 (2.5.27-1build2) ...
# Selecting previously unselected package libgphoto2-l10n.
# Preparing to unpack .../33-libgphoto2-l10n_2.5.27-1build2_all.deb ...
# Unpacking libgphoto2-l10n (2.5.27-1build2) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../34-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libgtk-3-common.
# Preparing to unpack .../35-libgtk-3-common_3.24.33-1ubuntu2.2_all.deb ...
# Unpacking libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-0:amd64.
# Preparing to unpack .../36-libgtk-3-0_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-bin.
# Preparing to unpack .../37-libgtk-3-bin_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-bin (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libilmbase25:amd64.
# Preparing to unpack .../38-libilmbase25_2.5.7-2_amd64.deb ...
# Unpacking libilmbase25:amd64 (2.5.7-2) ...
# Selecting previously unselected package libilmbase-dev:amd64.
# Preparing to unpack .../39-libilmbase-dev_2.5.7-2_amd64.deb ...
# Unpacking libilmbase-dev:amd64 (2.5.7-2) ...
# Selecting previously unselected package libtbbmalloc2:amd64.
# Preparing to unpack .../40-libtbbmalloc2_2021.5.0-7ubuntu2_amd64.deb ...
# Unpacking libtbbmalloc2:amd64 (2021.5.0-7ubuntu2) ...
# Selecting previously unselected package libtbb12:amd64.
# Preparing to unpack .../41-libtbb12_2021.5.0-7ubuntu2_amd64.deb ...
# Unpacking libtbb12:amd64 (2021.5.0-7ubuntu2) ...
# Selecting previously unselected package libopencv-core4.5d:amd64.
# Preparing to unpack .../42-libopencv-core4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-core4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-flann4.5d:amd64.
# Preparing to unpack .../43-libopencv-flann4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-flann4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-imgproc4.5d:amd64.
# Preparing to unpack .../44-libopencv-imgproc4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-imgproc4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-features2d4.5d:amd64.
# Preparing to unpack .../45-libopencv-features2d4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-features2d4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-calib3d4.5d:amd64.
# Preparing to unpack .../46-libopencv-calib3d4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-calib3d4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libtbb-dev:amd64.
# Preparing to unpack .../47-libtbb-dev_2021.5.0-7ubuntu2_amd64.deb ...
# Unpacking libtbb-dev:amd64 (2021.5.0-7ubuntu2) ...
# Selecting previously unselected package libopencv-core-dev:amd64.
# Preparing to unpack .../48-libopencv-core-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-core-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-flann-dev:amd64.
# Preparing to unpack .../49-libopencv-flann-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-flann-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopenexr25:amd64.
# Preparing to unpack .../50-libopenexr25_2.5.7-1_amd64.deb ...
# Unpacking libopenexr25:amd64 (2.5.7-1) ...
# Selecting previously unselected package libopencv-imgcodecs4.5d:amd64.
# Preparing to unpack .../51-libopencv-imgcodecs4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-imgcodecs4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-highgui4.5d:amd64.
# Preparing to unpack .../52-libopencv-highgui4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-highgui4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-imgproc-dev:amd64.
# Preparing to unpack .../53-libopencv-imgproc-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-imgproc-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-imgcodecs-dev:amd64.
# Preparing to unpack .../54-libopencv-imgcodecs-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-imgcodecs-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-videoio4.5d:amd64.
# Preparing to unpack .../55-libopencv-videoio4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-videoio4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-videoio-dev:amd64.
# Preparing to unpack .../56-libopencv-videoio-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-videoio-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopenexr-dev.
# Preparing to unpack .../57-libopenexr-dev_2.5.7-1_amd64.deb ...
# Unpacking libopenexr-dev (2.5.7-1) ...
# Selecting previously unselected package libswscale-dev:amd64.
# Preparing to unpack .../58-libswscale-dev_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libswscale-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libopencv-highgui-dev:amd64.
# Preparing to unpack .../59-libopencv-highgui-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-highgui-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-ml4.5d:amd64.
# Preparing to unpack .../60-libopencv-ml4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-ml4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-ml-dev:amd64.
# Preparing to unpack .../61-libopencv-ml-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-ml-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-features2d-dev:amd64.
# Preparing to unpack .../62-libopencv-features2d-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-features2d-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-calib3d-dev:amd64.
# Preparing to unpack .../63-libopencv-calib3d-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-calib3d-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-dnn4.5d:amd64.
# Preparing to unpack .../64-libopencv-dnn4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-dnn4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-objdetect4.5d:amd64.
# Preparing to unpack .../65-libopencv-objdetect4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-objdetect4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-video4.5d:amd64.
# Preparing to unpack .../66-libopencv-video4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-video4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-contrib4.5d:amd64.
# Preparing to unpack .../67-libopencv-contrib4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-contrib4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-dnn-dev:amd64.
# Preparing to unpack .../68-libopencv-dnn-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-dnn-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-objdetect-dev:amd64.
# Preparing to unpack .../69-libopencv-objdetect-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-objdetect-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-photo4.5d:amd64.
# Preparing to unpack .../70-libopencv-photo4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-photo4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-photo-dev:amd64.
# Preparing to unpack .../71-libopencv-photo-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-photo-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-shape4.5d:amd64.
# Preparing to unpack .../72-libopencv-shape4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-shape4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-video-dev:amd64.
# Preparing to unpack .../73-libopencv-video-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-video-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-shape-dev:amd64.
# Preparing to unpack .../74-libopencv-shape-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-shape-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-stitching4.5d:amd64.
# Preparing to unpack .../75-libopencv-stitching4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-stitching4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-stitching-dev:amd64.
# Preparing to unpack .../76-libopencv-stitching-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-stitching-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-superres4.5d:amd64.
# Preparing to unpack .../77-libopencv-superres4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-superres4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-superres-dev:amd64.
# Preparing to unpack .../78-libopencv-superres-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-superres-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-videostab4.5d:amd64.
# Preparing to unpack .../79-libopencv-videostab4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-videostab4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-videostab-dev:amd64.
# Preparing to unpack .../80-libopencv-videostab-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-videostab-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libvtk9.1:amd64.
# Preparing to unpack .../81-libvtk9.1_9.1.0+really9.1.0+dfsg2-3build1+jammy1_amd64.deb ...
# Unpacking libvtk9.1:amd64 (9.1.0+really9.1.0+dfsg2-3build1+jammy1) ...
# Selecting previously unselected package libopencv-viz4.5d:amd64.
# Preparing to unpack .../82-libopencv-viz4.5d_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-viz4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-viz-dev:amd64.
# Preparing to unpack .../83-libopencv-viz-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-viz-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-contrib-dev:amd64.
# Preparing to unpack .../84-libopencv-contrib-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-contrib-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv-dev.
# Preparing to unpack .../85-libopencv-dev_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv-dev (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv4.5d-jni.
# Preparing to unpack .../86-libopencv4.5d-jni_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv4.5d-jni (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libopencv4.5-java.
# Preparing to unpack .../87-libopencv4.5-java_4.5.4+dfsg-9ubuntu4+jammy1_amd64.deb ...
# Unpacking libopencv4.5-java (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Selecting previously unselected package libraw1394-tools.
# Preparing to unpack .../88-libraw1394-tools_2.1.2-2build2_amd64.deb ...
# Unpacking libraw1394-tools (2.1.2-2build2) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../89-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package opencv-data.
# Preparing to unpack .../90-opencv-data_4.5.4+dfsg-9ubuntu4+jammy1_all.deb ...
# Unpacking opencv-data (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libavutil-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libtbbmalloc2:amd64 (2021.5.0-7ubuntu2) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libdouble-conversion3:amd64 (3.1.7-4) ...
# Setting up libcharls2:amd64 (2.3.4-1) ...
# Setting up libswresample-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Setting up libavcodec-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libraw1394-dev:amd64 (2.1.2-2build2) ...
# Setting up libilmbase25:amd64 (2.5.7-2) ...
# Setting up libavformat-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libtbb12:amd64 (2021.5.0-7ubuntu2) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up libgphoto2-l10n (2.5.27-1build2) ...
# Setting up libgl2ps1.4 (1.4.2+dfsg1-2) ...
# Setting up libopenexr25:amd64 (2.5.7-1) ...
# Setting up libswscale-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libexif12:amd64 (0.6.24-1build1) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Setting up pkg-config (0.29.2-1ubuntu3) ...
# Setting up libsocket++1:amd64 (1.12.13+git20131030.5d039ba-1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libglew2.2:amd64 (2.2.0-4) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up opencv-data (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libexif-doc (0.6.24-1build1) ...
# Setting up libraw1394-tools (2.1.2-2build2) ...
# Setting up libopencv-core4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libtbb-dev:amd64 (2021.5.0-7ubuntu2) ...
# Setting up libgphoto2-port12:amd64 (2.5.27-1build2) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Setting up libilmbase-dev:amd64 (2.5.7-2) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up libopencv-imgproc4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-flann4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libexif-dev:amd64 (0.6.24-1build1) ...
# Setting up libopencv-photo4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libdc1394-dev:amd64 (2.2.6-4) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up libopencv-features2d4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-ml4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libvtk9.1:amd64 (9.1.0+really9.1.0+dfsg2-3build1+jammy1) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libgphoto2-6:amd64 (2.5.27-1build2) ...
# Setting up libopenexr-dev (2.5.7-1) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up libgdcm3.0:amd64 (3.0.10-1build2) ...
# Setting up libopencv-dnn4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-core-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-viz4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-calib3d4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-imgcodecs4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-flann-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libgdcm-dev (3.0.10-1build2) ...
# Setting up libopencv-ml-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-videoio4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libgphoto2-dev:amd64 (2.5.27-1build2) ...
# Setting up libopencv-video4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-imgproc-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-dnn-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-objdetect4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-stitching4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-viz-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-shape4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-video-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-shape-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-videostab4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-photo-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-imgcodecs-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-videoio-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.6) ...
# Setting up libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Setting up libgtk-3-bin (3.24.33-1ubuntu2.2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Setting up libopencv-highgui4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up at-spi2-core (2.44.0-3) ...
# Setting up libopencv-highgui-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-features2d-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.4) ...
# Setting up libopencv-calib3d-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-objdetect-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-contrib4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-superres4.5d:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-videostab-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-stitching-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv4.5d-jni (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-superres-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv4.5-java (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-contrib-dev:amd64 (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Setting up libopencv-dev (4.5.4+dfsg-9ubuntu4+jammy1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link

# %%
# %%writefile cpu_blur.cpp
# #include <opencv2/opencv.hpp>
# #include <iostream>
# #include <chrono>
#
# #include <opencv2/opencv.hpp>
# #include <iostream>
# #include <chrono>
#
# int main() {
#     // Loaded the input image in grayscale format
#     cv::Mat img = cv::imread("/content/download.jpg", cv::IMREAD_GRAYSCALE);
#     if (img.empty()) {
#         std::cout << "Error loading image\n";
#         return -1;
#     }
#
#     // Stored image width and height for processing
#     int w = img.cols;
#     int h = img.rows;
#
#     // Created the output image by copying the input image
#     cv::Mat result = img.clone();
#
#     // Started measuring CPU execution time
#     auto start = std::chrono::high_resolution_clock::now();
#
#     // Defined a 3x3 Gaussian kernel
#     int kernel[3][3] = {
#         {1, 2, 1},
#         {2, 4, 2},
#         {1, 2, 1}
#     };
#
#     // Applied Gaussian blur while skipping border pixels
#     for (int y = 1; y < h - 1; y++) {
#         for (int x = 1; x < w - 1; x++) {
#             int sum = 0;
#
#             // Computed weighted sum of neighboring pixels
#             for (int ky = -1; ky <= 1; ky++) {
#                 for (int kx = -1; kx <= 1; kx++) {
#                     sum += img.at<uchar>(y + ky, x + kx) *
#                            kernel[ky + 1][kx + 1];
#                 }
#             }
#
#             // Normalized the result and stored it in the blurred pixel
#             result.at<uchar>(y, x) = sum / 16;
#         }
#     }
#
#     // Stopped timing after the blur computation finished
#     auto end = std::chrono::high_resolution_clock::now();
#     auto duration =
#         std::chrono::duration_cast<std::chrono::milliseconds>(end - start);
#
#     // Saved the CPU processed output image
#     cv::imwrite("cpu_output.jpg", result);
#
#     // Printed the total CPU execution time
#     std::cout << "CPU time: " << duration.count() << " ms\n";
#
#     return 0;
# }
# Out:
# Overwriting cpu_blur.cpp

# %%
# !g++ cpu_blur.cpp -o cpu_blur `pkg-config --cflags --libs opencv4`

# %%
# !./cpu_blur
# Out:
# CPU time: 12 ms

# %%
# %%writefile gpu_blur.cu
# #include <opencv2/opencv.hpp>
# #include <cuda_runtime.h>
# #include <iostream>
#
# // Defined a simple CUDA kernel for Gaussian blur
# __global__ void blurKernel(unsigned char* in, unsigned char* out, int w, int h) {
#     int x = blockIdx.x * blockDim.x + threadIdx.x;
#     int y = blockIdx.y * blockDim.y + threadIdx.y;
#
#     // Checked if the thread was inside image bounds
#     if (x >= w || y >= h) return;
#
#     // Defined a 3x3 Gaussian kernel
#     int kernel[3][3] = {
#         {1, 2, 1},
#         {2, 4, 2},
#         {1, 2, 1}
#     };
#
#     int sum = 0;
#
#     // Applied blur only for non-border pixels
#     if (x > 0 && x < w - 1 && y > 0 && y < h - 1) {
#         for (int ky = -1; ky <= 1; ky++) {
#             for (int kx = -1; kx <= 1; kx++) {
#                 sum += in[(y + ky) * w + (x + kx)] *
#                        kernel[ky + 1][kx + 1];
#             }
#         }
#
#         // Normalized the result and stored it in output
#         out[y * w + x] = sum / 16;
#     }
#     else {
#         // Copied border pixels directly without modification
#         out[y * w + x] = in[y * w + x];
#     }
# }
#
# int main() {
#     // Loaded the input image in grayscale format
#     cv::Mat img = cv::imread("/content/download.jpg", cv::IMREAD_GRAYSCALE);
#     if (img.empty()) {
#         std::cout << "Error loading image\n";
#         return -1;
#     }
#
#     // Stored image width, height, and total size
#     int w = img.cols;
#     int h = img.rows;
#     int size = w * h;
#
#     // Allocated memory on the GPU
#     unsigned char *d_in, *d_out;
#     cudaMalloc(&d_in, size);
#     cudaMalloc(&d_out, size);
#
#     // Copied the input image from host to device
#     cudaMemcpy(d_in, img.data, size, cudaMemcpyHostToDevice);
#
#     // Configured CUDA grid and block dimensions
#     dim3 block(16, 16);
#     dim3 grid((w + 15) / 16, (h + 15) / 16);
#
#     // Created CUDA events for timing
#     cudaEvent_t start, stop;
#     cudaEventCreate(&start);
#     cudaEventCreate(&stop);
#
#     // Recorded the start time and launched the kernel
#     cudaEventRecord(start);
#     blurKernel<<<grid, block>>>(d_in, d_out, w, h);
#     cudaEventRecord(stop);
#     cudaEventSynchronize(stop);
#
#     // Calculated the GPU execution time
#     float time;
#     cudaEventElapsedTime(&time, start, stop);
#
#     // Copied the result back from device to host
#     cv::Mat result(h, w, CV_8UC1);
#     cudaMemcpy(result.data, d_out, size, cudaMemcpyDeviceToHost);
#
#     // Saved the GPU processed output image
#     cv::imwrite("gpu_output.jpg", result);
#
#     // Printed the kernel execution time
#     std::cout << "GPU time: " << time << " ms\n";
#
#     // Freed allocated GPU memory
#     cudaFree(d_in);
#     cudaFree(d_out);
#
#     return 0;
# }
# Out:
# Overwriting gpu_blur.cu

# %%
# !nvcc gpu_blur.cu -o gpu_blur \
  `pkg-config --cflags --libs opencv4` \
  -arch=sm_75
# Out:
# /usr/include/opencv4/opencv2/stitching/detail/warpers.hpp(235): warning #611-D: overloaded virtual function "cv::detail::PlaneWarper::buildMaps" is only partially overridden in class "cv::detail::AffineWarper"
#   class AffineWarper : public PlaneWarper
#         ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# /usr/include/opencv4/opencv2/stitching/detail/warpers.hpp(235): warning #611-D: overloaded virtual function "cv::detail::PlaneWarper::warp" is only partially overridden in class "cv::detail::AffineWarper"
#   class AffineWarper : public PlaneWarper
#         ^
#
# /usr/include/opencv4/opencv2/stitching/detail/blenders.hpp(100): warning #611-D: overloaded virtual function "cv::detail::Blender::prepare" is only partially overridden in class "cv::detail::FeatherBlender"
#   class FeatherBlender : public Blender
#         ^
#
# /usr/include/opencv4/opencv2/stitching/detail/blenders.hpp(127): warning #611-D: overloaded virtual function "cv::detail::Blender::prepare" is only partially overridden in class "cv::detail::MultiBandBlender"
#   class MultiBandBlender : public Blender
#         ^
#
# /usr/include/opencv4/opencv2/stitching/detail/warpers.hpp(235): warning #611-D: overloaded virtual function "cv::detail::PlaneWarper::buildMaps" is only partially overridden in class "cv::detail::AffineWarper"
#   class AffineWarper : public PlaneWarper
#         ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# /usr/include/opencv4/opencv2/stitching/detail/warpers.hpp(235): warning #611-D: overloaded virtual function "cv::detail::PlaneWarper::warp" is only partially overridden in class "cv::detail::AffineWarper"
#   class AffineWarper : public PlaneWarper
#         ^
#
# /usr/include/opencv4/opencv2/stitching/detail/blenders.hpp(100): warning #611-D: overloaded virtual function "cv::detail::Blender::prepare" is only partially overridden in class "cv::detail::FeatherBlender"
#   class FeatherBlender : public Blender
#         ^
#
# /usr/include/opencv4/opencv2/stitching/detail/blenders.hpp(127): warning #611-D: overloaded virtual function "cv::detail::Blender::prepare" is only partially overridden in class "cv::detail::MultiBandBlender"
#   class MultiBandBlender : public Blender
#         ^

# %%
# !./gpu_blur
# Out:
# GPU time: 0.102272 ms

# %%
import cv2
import subprocess
import os

print("=== Gaussian Blur Comparison ===")

# Ran the GPU program to generate the GPU output image
print("\nRunning GPU program...")
subprocess.run(["./gpu_blur"])

# Ran the CPU program to generate the CPU output image
print("\nRunning CPU program...")
subprocess.run(["./cpu_blur"])

# Loaded the output images produced by GPU and CPU programs
gpu_img = cv2.imread("gpu_output.jpg", 0)
cpu_img = cv2.imread("cpu_output.jpg", 0)

# Checked whether both output images were loaded correctly
if gpu_img is None or cpu_img is None:
    print("Error loading output images")
    exit()

# Compared the two output images pixel by pixel
if gpu_img.shape == cpu_img.shape:
    diff = cv2.absdiff(gpu_img, cpu_img)
    same_pixels = (diff == 0).sum()
    total_pixels = gpu_img.shape[0] * gpu_img.shape[1]

    print(f"\n=== Results ===")
    print(f"Total pixels: {total_pixels}")
    print(f"Matching pixels: {same_pixels}")
    print(f"Accuracy: {100 * same_pixels / total_pixels:.2f}%")

    if same_pixels == total_pixels:
        print("✓ Perfect match!")
    else:
        print("⚠ Small differences found")
else:
    print("Error: Output sizes don't match")
# Out:
# === Gaussian Blur Comparison ===
#
# Running GPU program...
#
# Running CPU program...
#
# === Results ===
# Total pixels: 50325
# Matching pixels: 50325
# Accuracy: 100.00%
# ✓ Perfect match!
